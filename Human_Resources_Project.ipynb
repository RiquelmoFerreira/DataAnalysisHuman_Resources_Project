# %% [markdown]
# # About the Project
# ## Analyzing the Year Experience x Salary

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading

# %%
Data_Set = pd.read_csv('Salary_Data.csv')
Data_Set.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
Data_Set.shape
# Out:
# (30, 2)

# %% [markdown]
# ### Nulls Records

# %%
Data_Set.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# ### Statistics

# %%
Data_Set.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# ### Salary Analysis

# %%
plt.figure(figsize=(10, 6))
plt.title('Salary Analysis')
sns.kdeplot(Data_Set['Salary'], color='green');

# %% [markdown]
# ### Years Experience Analysis

# %%
plt.figure(figsize=(10, 6))
plt.title('Years Experience Analysis')
sns.kdeplot(Data_Set['YearsExperience'],  color='blue');

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(Data_Set['Salary'], orient='h')
plt.yticks([])
plt.xlabel('Salary');

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(Data_Set['YearsExperience'], orient='h')
plt.yticks([])
plt.xlabel('Years Experience');

# %% [markdown]
# ### Scatterplot

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=Data_Set, x='Salary', y='YearsExperience');

# %%
plt.figure(figsize=(10, 5))
sns.regplot(data=Data_Set, x='Salary', y='YearsExperience');

# %% [markdown]
# ### Correlation

# %%
Correlation = Data_Set.corr()
plt.figure(figsize=(10, 5))
sns.heatmap(Correlation, annot=True, cbar=False);
